# %% [markdown]
# ## Flow of Information and Cascading Behavior Through the Western States Power Grid - Cascade Random (N=1000)
#
# ### Tucker Knaak - Department of Mathematics, Creighton University - 2023
#
# #### A cascade is defined as a sequence of chain reactions through a network, and a complete cascade results in the entire network being affected by the chain reactions.  A cluster of nodes has a densiy $p$ if each node in the set has at least a $p$ fraction of its neighbors in the cluster.  It can be shown that there exists a threshold $q$, such that a complete cascade cannot occur if a cluster of nodes in the network has a density $p>1-q$.  In this code, we will begin by having 1000 random nodes fail.  We will then determine whether these failed nodes will cause a complete through the network for different threshold values.

# %%
import matplotlib.transforms as mtransforms
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import community
from IPython.display import HTML
from tabulate import tabulate
np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# %% [markdown]
# #### This cell runs the wspg.ipynb Jupyter notebook to call the power_grid() class.

# %%
# %run wspg.ipynb

# %% [markdown]
# #### The following cells simulate a cascade through the network for 1000 random failed initial nodes and a threshold of q=0.10.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadernd_N1000_q10 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 1000 Random Nodes Failed',
                                        'cascadernd_N1000_q10')
cascadernd_N1000_q10.cascade_random(1000, 0.1)

# %%
cascadernd_N1000_q10.animate_cascade_random()

# %% [markdown]
# #### The following cells simulate a cascade through the network for 1000 random failed initial nodes and a threshold of q=0.20.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadernd_N1000_q20 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 1000 Random Nodes Failed',
                                        'cascadernd_N1000_q20')
cascadernd_N1000_q20.cascade_random(1000, 0.2)

# %%
cascadernd_N1000_q20.animate_cascade_random()

# %% [markdown]
# #### The following cells simulate a cascade through the network for 1000 random failed initial nodes and a threshold of q=0.30.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadernd_N1000_q30 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 1000 Random Nodes Failed',
                                        'cascadernd_N1000_q30')
cascadernd_N1000_q30.cascade_random(1000, 0.3)

# %%
cascadernd_N1000_q30.animate_cascade_random()

# %% [markdown]
# #### The following cells simulate a cascade through the network for 1000 random failed initial nodes and a threshold of q=0.40.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadernd_N1000_q40 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 1000 Random Nodes Failed',
                                        'cascadernd_N1000_q40')
cascadernd_N1000_q40.cascade_random(1000, 0.4)

# %%
cascadernd_N1000_q40.animate_cascade_random()

# %% [markdown]
# #### The following cells simulate a cascade through the network for 1000 random failed initial nodes and a threshold of q=0.50.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadernd_N1000_q50 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 1000 Random Nodes Failed',
                                        'cascadernd_N1000_q50')
cascadernd_N1000_q50.cascade_random(1000, 0.5)

# %%
cascadernd_N1000_q50.animate_cascade_random()
