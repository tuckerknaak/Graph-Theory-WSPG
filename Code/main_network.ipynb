# %% [markdown]
# ## Flow of Information and Cascading Behavior Through the Western States Power Grid - Main Network
#
# ### Tucker Knaak - Department of Mathematics, Creighton University - 2023
#
# #### In this code, we draw the Western States Power Grid of the United States, find the Louvain communities, and calculate the global and local efficiencies, the density, and the edge and node betweenness centralities.

# %%
import matplotlib.transforms as mtransforms
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import community
from IPython.display import HTML
from tabulate import tabulate
np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# %% [markdown]
# #### This cell runs the wspg.ipynb Jupyter notebook to call the power_grid() class.

# %%
# %run wspg.ipynb

# %% [markdown]
# #### This cell draws the network and calculates the global and local efficiencies as well as the clustering coefficient of the network.

# %%
wspg = power_grid(nx.read_gml('power.gml', label = 'id'), '', 'wspg')
print(wspg.network)
wspg.draw_network(wspg.pos, wspg.community_node_cmap)
# Out:
# Graph with 4941 nodes and 6594 edges

# %% [markdown]
# #### This cell creates a table of the Louvain Communities in the network and calculates the number of nodes, density, and total betweenness centrality of each community.

# %%
wspg.community_table()

# %% [markdown]
# #### This cell plots the edge and node betweenness centralities of the network.

# %%
wspg.plot_bc()
