# %% [markdown]
# ## Flow of Information and Cascading Behavior Through the Western States Power Grid - Cascade Node BC (N=100)
#
# ### Tucker Knaak - Department of Mathematics, Creighton University - 2023
#
# #### A cascade is defined as a sequence of chain reactions through a network, and a complete cascade results in the entire network being affected by the chain reactions.  A cluster of nodes has a densiy $p$ if each node in the set has at least a $p$ fraction of its neighbors in the cluster.  It can be shown that there exists a threshold $q$, such that a complete cascade cannot occur if a cluster of nodes in the network has a density $p>1-q$.  In this code, we will begin by having 100 nodes with the largest betweenness centrality fail.  We will then determine whether these failed nodes will cause a complete through the network for different threshold values.

# %%
import matplotlib.transforms as mtransforms
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import community
from IPython.display import HTML
from tabulate import tabulate
np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# %% [markdown]
# #### This cell runs the wspg.ipynb Jupyter notebook to call the power_grid() class.

# %%
# %run wspg.ipynb

# %% [markdown]
# #### The following cells simulate a cascade through the network for 100 failed initial nodes with the largest betweenness centrality and a threshold of q=0.10.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadenodebc_N100_q10 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 100 Nodes with Largest BC Failed',
                                        'cascadenodebc_N100_q10')
cascadenodebc_N100_q10.cascade_nodebc(100, 0.1)

# %%
cascadenodebc_N100_q10.animate_cascade_nodebc()

# %% [markdown]
# #### The following cells simulate a cascade through the network for 100 failed initial nodes with the largest betweenness centrality and a threshold of q=0.20.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadenodebc_N100_q20 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 100 Nodes with Largest BC Failed',
                                        'cascadenodebc_N100_q20')
cascadenodebc_N100_q20.cascade_nodebc(100, 0.2)

# %%
cascadenodebc_N100_q20.animate_cascade_nodebc()

# %% [markdown]
# #### The following cells simulate a cascade through the network for 100 failed initial nodes with the largest betweenness centrality and a threshold of q=0.30.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadenodebc_N100_q30 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 100 Nodes with Largest BC Failed',
                                        'cascadenodebc_N100_q30')
cascadenodebc_N100_q30.cascade_nodebc(100, 0.3)

# %%
cascadenodebc_N100_q30.animate_cascade_nodebc()
# Out:
# Animation size has reached 21236749 bytes, exceeding the limit of 20971520.0. If you're sure you want a larger animation embedded, set the animation.embed_limit rc parameter to a larger value (in MB). This and further frames will be dropped.

# %% [markdown]
# #### The following cells simulate a cascade through the network for 100 failed initial nodes with the largest betweenness centrality and a threshold of q=0.40.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadenodebc_N100_q40 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 100 Nodes with Largest BC Failed',
                                        'cascadenodebc_N100_q40')
cascadenodebc_N100_q40.cascade_nodebc(100, 0.4)

# %%
cascadenodebc_N100_q40.animate_cascade_nodebc()

# %% [markdown]
# #### The following cells simulate a cascade through the network for 100 failed initial nodes with the largest betweenness centrality and a threshold of q=0.50.  The network is drawn at each step and saved as a .png, and then the cascade is animated and saved as a .gif.

# %%
cascadenodebc_N100_q50 = power_grid(nx.read_gml('power.gml', label = 'id'), '- 100 Nodes with Largest BC Failed',
                                        'cascadenodebc_N100_q50')
cascadenodebc_N100_q50.cascade_nodebc(100, 0.5)

# %%
cascadenodebc_N100_q50.animate_cascade_nodebc()
